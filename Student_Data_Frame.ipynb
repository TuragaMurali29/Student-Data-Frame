# %% [markdown]
# <a href="https://colab.research.google.com/github/TuragaMurali29/Student-Data-Frame/blob/main/Student_Data_Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
len(a1)
# Out:
# 0

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df={
    'grade':a1,
    'weight':a2,
    'friends':a3,
    'couisins':a4,
    'projects':a5,
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  couisins  projects
# 0       53      62       12        10        47
# 1       45      65       18         6        38
# 2       73      56       12         7        63
# 3       76      56       17        10        55
# 4        1      62       20         9        24
# ..     ...     ...      ...       ...       ...
# 995     69      58       16         9        37
# 996     47      70       12         5        38
# 997     62      52       10         5        55
# 998     89      69       10        10        52
# 999     84      58       11         5        53
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends     couisins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     50.076000    60.521000    15.068000     7.502000    49.643000
# std      29.677921     6.076222     3.103709     1.681316    17.796355
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      24.000000    55.000000    12.000000     6.000000    34.000000
# 50%      50.000000    61.000000    15.000000     7.000000    50.000000
# 75%      76.000000    66.000000    18.000000     9.000000    65.000000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1['grade']
# Out:
# 0      53
# 1      45
# 2      73
# 3      76
# 4       1
#        ..
# 995    69
# 996    47
# 997    62
# 998    89
# 999    84
# Name: grade, Length: 1000, dtype: int64

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      53
# 1      45
# 2      73
# 3      76
# 4       1
#        ..
# 995    69
# 996    47
# 997    62
# 998    89
# 999    84
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15=df1['friends'] > 15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  couisins  projects
# 1       45      65       18         6        38
# 3       76      56       17        10        55
# 4        1      62       20         9        24
# 6       67      50       19         7        63
# 7       21      52       16         8        65
# ..     ...     ...      ...       ...       ...
# 984     70      57       17        10        77
# 986     88      69       19         7        69
# 988     32      70       18        10        20
# 993     63      67       20         8        78
# 995     69      58       16         9        37
#
# [471 rows x 5 columns]

# %%
grade50=df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  couisins  projects
# 0       53      62       12        10        47
# 2       73      56       12         7        63
# 3       76      56       17        10        55
# 5       86      65       14        10        32
# 6       67      50       19         7        63
# ..     ...     ...      ...       ...       ...
# 994     52      62       15         8        29
# 995     69      58       16         9        37
# 997     62      52       10         5        55
# 998     89      69       10        10        52
# 999     84      58       11         5        53
#
# [496 rows x 5 columns]

# %%
df1[friend15 & grade50].describe()
# Out:
#             grade      weight     friends    couisins    projects
# count  235.000000  235.000000  235.000000  235.000000  235.000000
# mean    76.127660   59.953191   17.834043    7.429787   48.187234
# std     14.575792    6.182580    1.474176    1.584637   18.165168
# min     52.000000   50.000000   16.000000    5.000000   20.000000
# 25%     64.000000   55.000000   17.000000    6.000000   32.000000
# 50%     75.000000   60.000000   18.000000    7.000000   47.000000
# 75%     89.000000   65.500000   19.000000    9.000000   62.500000
# max    100.000000   70.000000   20.000000   10.000000   80.000000

# %%
grade98 = df1['grade'] > 98

# %%
df1 [friend18 & grade98]['friends']
# Out:
# 127    20
# 151    19
# 859    20
# Name: friends, dtype: int64

# %%
# %matplotlib inline

# %%
import pandas as pd
df1 = pd.DataFrame(df)
friend15 = df1['friends'] > 15
grade75 = df1['grade'] > 75
df1[friend15 & grade75].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade75].plot(x='grade',y='projects',kind='area')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade75].plot(x='grade', y='projects', kind='pie')
# Out:
# <Axes: ylabel='projects'>

# %%
df1[friend15 & grade75].plot(x='grade', y='projects', kind='box')
# Out:
# <Axes: >

# %%
df1[friend15 & grade75].plot(x= 'grade',y= 'projects',kind='scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friend15 & grade75].plot(x='grade', y='projects', kind='area', title='Sample Graph')
# Out:
# <Axes: title={'center': 'Sample Graph'}, xlabel='grade'>

# %%
fdf = df1[friend15 & grade75]
fdf.plot(x='grade', y='projects', kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
fdf = df1[friend15 & grade75]

# %%
fdf
# Out:
#      grade  weight  friends  couisins  projects
# 3       76      56       17        10        55
# 13      95      67       17         9        26
# 28      98      55       19         7        41
# 54      93      61       18         5        22
# 70      81      50       17         7        57
# ..     ...     ...      ...       ...       ...
# 943     84      55       16         7        48
# 946     82      51       16         7        32
# 948    100      60       18         8        58
# 971    100      66       18         5        35
# 986     88      69       19         7        69
#
# [114 rows x 5 columns]

# %%
df1
# Out:
#      grade  weight  friends  couisins  projects
# 0       53      62       12        10        47
# 1       45      65       18         6        38
# 2       73      56       12         7        63
# 3       76      56       17        10        55
# 4        1      62       20         9        24
# ..     ...     ...      ...       ...       ...
# 995     69      58       16         9        37
# 996     47      70       12         5        38
# 997     62      52       10         5        55
# 998     89      69       10        10        52
# 999     84      58       11         5        53
#
# [1000 rows x 5 columns]

# %%
df1.to_csv('/feb6TestData.csv')
